# %% [markdown]
# # Урок 4. Парсинг HTML. XPath

# %% [markdown]
# 1)Написать приложение, которое собирает основные новости с сайтов mail.ru и lenta.ru.
#
# 2) (Дополнительно) Собрать все новости со страницы https://yandex.ru/news/
#
# Для парсинга использовать xpath. Структура данных должна содержать:
# * название источника,
# * наименование новости,
# * ссылку на новость,
# * дата публикации

# %%
import requests as req
import pandas as pd
from lxml import html
from datetime import datetime, timedelta
import locale

# %% [markdown]
# **user_agent_mob** - для запроса к мобильной версии яндекс новостей
# **locale.setlocale(locale.LC_TIME, '')** - для обработки даты публикации(месяц написан буквами) с ленты

# %%
user_agent = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/78.0.3904.108 Safari/537.36'
user_agent_mob = 'Mozilla/5.0 (Linux; Android 5.1.1; Nexus 5 Build/LMY48B; wv) AppleWebKit/537.36 (KHTML, like Gecko) Version/4.0 Chrome/43.0.2357.65 Mobile Safari/537.36'
locale.setlocale(locale.LC_TIME, '')
# Out:
# 'ru_RU.UTF-8'

# %% [markdown]
# **ma_params, le_params, ya_params**
# индивидуальные параметры для каждого сайта

# %%
ma_params = {'headers' : {'User-Agent': user_agent},
             'link' : 'https://m.mail.ru/',
             'news_block' : '//div[@id="news-0"]',
             'href' : './/a[contains(@class,"list__item")]/@href',
             'href_prefix' : '',
             'title' : './/span[contains(@class,"list__item__title")]/text()',
             'datetime' : './/*[@class="note__text breadcrumbs__text js-ago"]/@datetime',
             'datetime_format' : ['%Y-%m-%d%H:%M:%S']}

# %%
le_params = {'headers' : {'User-Agent': user_agent},
             'link' : 'https://m.lenta.ru/',
             'news_block' : '//ul[@class="b-list b-list_top-7"]',
             'href' : './/a[@class="b-list-item__link"]/@href', 
             'href_prefix' : 'https://m.lenta.ru/',
             'title' : './/span[@class="b-list-item__title"]/text()',
             'datetime' : './/time[@class="g-time"]/@datetime',
             'datetime_format' : [' %H:%M, %d %B %Y']}

# %%
ya_params = {'headers' : {'User-Agent': user_agent_mob},
             'link' : 'https://yandex.ru/news/',
             'news_block' : '//div[@class="news-container"]',
             'href' : './/a[contains(@class,"Link link link_")]/@href',
             'href_prefix' : '',
             'title' : './/span[@class="link link_pseudo card__link"]/text()',
             'datetime' : './/span[@class="sport-date"]/text()',
             'datetime_format' : ['%H:%M', '%H:%M:%S%Y-%m-%d']}

# %% [markdown]
# **get_news** - получение основной информации
# **get_ma_datetime** - дата-время с мэйла (обходим ссылки с новостями)
# **datetime_format** - дата-время с разных сайтов - это строки в разном формате. преобразуем все к одному виду

# %%
class XPath_news_scraper:
    
    def datetime_format(self):
        for i in range(len(self.news['datetime'])): 
            news_datetime = datetime.strptime(self.news['datetime'][i], self.params['datetime_format'][0])
            if news_datetime.year == 1900:
                now = datetime.now()
                new = str(news_datetime.time())
                if now.time() > news_datetime.time():
                    new += str(now.date())
                else:
                    new += str((now - timedelta(days=1)).date())
                news_datetime = datetime.strptime(new, self.params['datetime_format'][1])
            self.news['datetime'][i] = news_datetime
    
    def get_ma_datetime(self):
        datetime = []
        for link in self.news['href']:
            response = req.get(link, headers=self.params['headers'])
            if response.status_code == 200:
                doc = html.fromstring(response.text) 
                try:
                    datetime.append(''.join(doc.xpath(self.params['datetime'])[0].replace('T', '+').split('+')[:-1]))
                except:
                    datetime.append(None)
            else:
                datetime.append(None)
        return datetime
        
    def get_news(self):
        response = req.get(self.params['link'], headers=self.params['headers'])
        if response.status_code == 200:
            doc = html.fromstring(response.text)
            try:
                news_block = doc.xpath(self.params['news_block'])
            except:
                return print('новости не найдены')
            self.news['site'] = self.params['link']
            try:
                self.news['title'] = news_block[0].xpath(self.params['title'])
            except:
                self.news['title'] = None
            try:
                self.news['href'] = [self.params['href_prefix'] + item for item in news_block[0].xpath(self.params['href'])]
            except:
                self.news['href'] = None
            if self.params['link'] != ma_params['link']:
                try:
                    self.news['datetime'] = news_block[0].xpath(self.params['datetime'])
                except:
                    self.news['datetime'] = None        
            else:
                self.news['datetime'] = self.get_ma_datetime()
            self.datetime_format()                
        else:
            print('что-то пошло не так: responce status code =', response.status_code)         
        
    def __init__(self, params):
        self.news = {}
        self.params = params
        self.get_news()

# %%
mail_scr = XPath_news_scraper(ma_params)

# %%
lenta_scr = XPath_news_scraper(le_params)

# %%
yandex_scr = XPath_news_scraper(ya_params)

# %%
df = pd.concat([pd.DataFrame(mail_scr.news), pd.DataFrame(lenta_scr.news), pd.DataFrame(yandex_scr.news)], ignore_index=True)

# %%
df
# Out:
#                        site  \
# 0        https://m.mail.ru/
# 1        https://m.mail.ru/
# 2        https://m.mail.ru/
# 3        https://m.mail.ru/
# 4        https://m.mail.ru/
# 5        https://m.mail.ru/
# 6        https://m.mail.ru/
# 7        https://m.mail.ru/
# 8       https://m.lenta.ru/
# 9       https://m.lenta.ru/
# 10      https://m.lenta.ru/
# 11      https://m.lenta.ru/
# 12      https://m.lenta.ru/
# 13      https://m.lenta.ru/
# 14      https://m.lenta.ru/
# 15      https://m.lenta.ru/
# 16      https://m.lenta.ru/
# 17      https://m.lenta.ru/
# 18  https://yandex.ru/news/
# 19  https://yandex.ru/news/
# 20  https://yandex.ru/news/
# 21  https://yandex.ru/news/
# 22  https://yandex.ru/news/
# 23  https://yandex.ru/news/
# 24  https://yandex.ru/news/
# 25  https://yandex.ru/news/
# 26  https://yandex.ru/news/
# 27  https://yandex.ru/news/
# 28  https://yandex.ru/news/
# 29  https://yandex.ru/news/
# ..                      ...
# 53  https://yandex.ru/news/
# 54  https://yandex.ru/news/
# 55  https://yandex.ru/news/
# 56  https://yandex.ru/news/
# 57  https://yandex.ru/news/
# 58  https://yandex.ru/news/
# 59  https://yandex.ru/news/
# 60  https://yandex.ru/news/
# 61  https://yandex.ru/news/
# 62  https://yandex.ru/news/
# 63  https://yandex.ru/news/
# 64  https://yandex.ru/news/
# 65  https://yandex.ru/news/
# 66  https://yandex.ru/news/
# 67  https://yandex.ru/news/
# 68  https://yandex.ru/news/
# 69  https://yandex.ru/news/
# 70  https://yandex.ru/news/
# 71  https://yandex.ru/news/
# 72  https://yandex.ru/news/
# 73  https://yandex.ru/news/
# 74  https://yandex.ru/news/
# 75  https://yandex.ru/news/
# 76  https://yandex.ru/news/
# 77  https://yandex.ru/news/
# 78  https://yandex.ru/news/
# 79  https://yandex.ru/news/
# 80  https://yandex.ru/news/
# 81  https://yandex.ru/news/
# 82  https://yandex.ru/news/
#
#                                                 title  \
# 0   США решили блокировать «Северный поток — 2» че...
# 1   Пилот рейса «Москва — Анапа» скончался после э...
# 2   Синоптики рассказали о последствиях арктическо...
# 3   Букву Ё вернули в названия 198 новгородских де...
# 4   Россиян поразило внезапно обнажившееся дно Азо...
# 5   Новый внедорожник для миллиардеров: он похож н...
# 6   Культовая техника 90-х: вспоминаем, как это бы...
# 7   «Какая красивая Аллочка»: Галкин показал новое...
# 8   Россиянин попытался отобрать пистолет у полице...
# 9   Красная книга России усомнилась в принадлежнос...
# 10                В России напали с ножом на таксиста
# 11  Девочки устроили массовую драку с мачете на се...
# 12  Россиянин зарезал сожительницу, угнал ее машин...
# 13  Массовая авария из-за покрывшейся льдом россий...
# 14  Мужчина с мачете 14 часов держал детей в залож...
# 15      Поклонская ответила Пушкову на критику Ротару
# 16  Стало известно о жалобах 23-летней следователь...
# 17  На Украине рассказали о «кошмарящей всю Европу...
# 18  Глава украинского Генштаба заявил о «кошмаряще...
# 19  Умер второй пилот экстренно приземлившегося в ...
# 20  В США анонсировали санкции против «Северного п...
# 21  Поклонская заступилась за Ротару, Вайкуле и Ка...
# 22    Синоптики предупредили о ледяном дожде в Москве
# 23       «Калашников» представил электромотоцикл «Иж»
# 24  Глава украинского Генштаба назвал тех, кто укр...
# 25  Риккардо — о соперничестве с «Торо Россо»: бит...
# 26    Юмашев объяснил выбор Путина преемником Ельцина
# 27    «Динамо» Киев — «Мариуполь»: неудобный соперник
# 28  Киссинджер рассказал о «холодной войне» между ...
# 29  Названа возможная причина жесткой посадки верт...
# ..                                                ...
# 53      The Economist показал карту Украины без Крыма
# 54           Страшный пожар в Кемерове попал на видео
# 55  Мадридский «Реал» обыграл «Реал Сосьедад» и до...
# 56  Росавтодор одобрил проект строительства моста ...
# 57  На федеральном канале показали, что происходил...
# 58  Россия станет третьим по величине рынком для в...
# 59                                 НДФЛ станет меньше
# 60  Минтранс усомнился в возобновлении чартеров в ...
# 61  В Петербурге задержали открывшего стрельбу из ...
# 62           Новую подводную лодку получит ВМФ России
# 63  Появилось видео столкновения машин на трассе Ч...
# 64  Будущий посол США назвал условие улучшения отн...
# 65  С-400 будут развернуты в Турции в автономном р...
# 66  Точный курс валют в Молдове: как поведут себя ...
# 67  Антон Батырев о работе над ролью в сериале «Ни...
# 68  Уральский банк извинился за выброшенные на ули...
# 69  Володин пообещал жителям Тёпловки новую школу ...
# 70  Полиция оштрафовала Шнура и Noize MC за мат на...
# 71  Министерство обороны Латвии обнаружило виновни...
