# %% [markdown]
# # Урок 2. Парсинг HTML. BeautifulSoup, MongoDB

# %% [markdown]
# Необходимо собрать информацию о вакансиях на вводимую должность (используем input или через аргументы) с сайта superjob.ru и hh.ru. Приложение должно анализировать несколько страниц сайта(также вводим через input или аргументы). Получившийся список должен содержать в себе минимум:
#
#     *Наименование вакансии
#     *Предлагаемую зарплату (отдельно мин. и отдельно макс.)
#     *Ссылку на саму вакансию
#     *Сайт откуда собрана вакансия
# По своему желанию можно добавить еще работодателя и расположение. Данная структура должна быть одинаковая для вакансий с обоих сайтов. Общий результат можно вывести с помощью dataFrame через pandas.

# %%
from bs4 import BeautifulSoup as bs
import requests as req
import pandas as pd
from random import randint as rndi
from time import sleep

# %%
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# #### собираем с hh мин, макс зп и валюту зп

# %%
def get_hh_compensations(item):
    try:
        vac_compensation = item.find('div', {'class':'vacancy-serp-item__compensation'}).getText()
    except:
        vac_compensation = 'None'
    if vac_compensation != 'None':
        vac_compensation = vac_compensation.split(' ')
        comp_curr = vac_compensation[-1]
        if vac_compensation[0] == 'от':
            min_compensation = ''.join(vac_compensation[1:-1])
            max_compensation = 'None'
        elif vac_compensation[0] == 'до':
            max_compensation = ''.join(vac_compensation[1:-1])
            min_compensation = 'None'
        else:
            min_compensation = vac_compensation[0].split('-')[0]
            max_compensation = vac_compensation[0].split('-')[1]   
    else:
        min_compensation, max_compensation, comp_curr = ['None'] * 3
    return min_compensation, max_compensation, comp_curr

# %% [markdown]
# #### собираем с superjob мин, макс зп и валюту зп

# %%
def get_sj_compensations(item):
    try:
        vac_compensation = item.find('span', {'class':'_3mfro _2Wp8I f-test-text-company-item-salary PlM3e _2JVkc _2VHxz'}).getText()
    except:
        vac_compensation = 'None'
    if vac_compensation != 'None':
        if vac_compensation == 'По договорённости':
            min_compensation = 'None'
            max_compensation = 'None'
            comp_curr = 'None'
        elif '—' in vac_compensation:
            vac_compensation = vac_compensation.split('—')
            comp_curr = vac_compensation[1][-1]
            max_compensation = vac_compensation[1][:-1]
            min_compensation = vac_compensation[0]
        elif 'от' in vac_compensation:
            vac_compensation = vac_compensation.split()
            comp_curr = vac_compensation[-1]
            max_compensation = 'None'
            min_compensation = ' '.join(vac_compensation[1:-1])
        elif 'до' in vac_compensation:
            vac_compensation = vac_compensation.split()
            comp_curr = vac_compensation[-1]
            max_compensation = ' '.join(vac_compensation[1:-1])
            min_compensation = 'None'
        else:
            vac_compensation = vac_compensation.split()
            comp_curr = vac_compensation[-1]
            max_compensation = ' '.join(vac_compensation[:-1])
            min_compensation = ' '.join(vac_compensation[:-1])
    else:
        min_compensation, max_compensation, comp_curr = ['None'] * 3
    return min_compensation, max_compensation, comp_curr

# %% [markdown]
# #### собираем с hh остальные данные. vac_name - название вакансии, vac_link - ссылка, employer- работодатель, location - местоположение

# %%
def get_hh_data(vacancies):
    for item in vacancies:
        site_name = hh
        try:
            vac_name = item.find('a').getText()
        except:
            vac_name = 'None'
        try:    
            vac_link = item.find('a')['href']
        except:
            vac_link = 'None'
        try:
            employer = item.find('a', {'data-qa':'vacancy-serp__vacancy-employer'}).getText()
        except:
            employer = 'None'
        try:    
            location = item.find('span', {'data-qa':'vacancy-serp__vacancy-address'}).getText()
        except:
            location = 'None'
        min_compensation, max_compensation, comp_curr = get_hh_compensations(item)
        df.loc[len(df) + 1] = [vac_name, employer, location, min_compensation, max_compensation, 
                                comp_curr, vac_link, site_name]

# %% [markdown]
# #### собираем с superjob остальные данные. vac_name - название вакансии, vac_link - ссылка, employer- работодатель, location - местоположение

# %%
def get_sj_data(vacancies):
    for item in vacancies:
        site_name = sj
        try:
            vacancy = item.find('div', {'class':'_3mfro CuJz5 PlM3e _2JVkc _3LJqf'})
            vac_name = vacancy.getText()
        except:
            vac_name = 'None'
        try:
            vac_link = sj + vacancy.findParent('a')['href']
        except:
            vac_link = 'None'
        try:
            employer = item.find('span', {'class':'_3mfro _3Fsn4 f-test-text-vacancy-item-company-name _9fXTd _2JVkc _3e53o _15msI'}).getText()          
        except:
            employer = 'None'
        try:
            location = item.find('span', {'class':'_3mfro f-test-text-company-item-location _9fXTd _2JVkc _3e53o'}).findChildren(limit=2)[1].getText()
        except:
            location = 'None'
        min_compensation, max_compensation, comp_curr = get_sj_compensations(item)
        df.loc[len(df) + 1] = [vac_name, employer, location, min_compensation, max_compensation, 
                                comp_curr, vac_link, site_name]

# %%
df = pd.DataFrame(columns=['vac_name', 'employer', 'location', 'min_compensation', 'max_compensation',
                          'currency', 'link', 'site_name'])

# %%
user_agent = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) \
Chrome/78.0.3904.97 Safari/537.36'
headers = {'User-Agent': user_agent}
hh = 'https://hh.ru'
sj = 'https://www.superjob.ru'

# %% [markdown]
# #### фомируем строку для поиска

# %%
search_text = input('Что ищем? ')
if search_text == '':
    search_text = 'Python'
# Out:
# Что ищем? грузчик

# %% [markdown]
# #### берем с hh количество вакансий и страниц по нашему запросу

# %%
response = req.get(hh + f'/search/vacancy?text={search_text}', headers=headers)
if response.ok:
    hh_parsed_html = bs(response.text,'lxml')
    try:
        hh_vacancies_total = hh_parsed_html.find('div', {'class':'breadcrumbs'}).next_sibling.getText()
    except:
        hh_vacancies_total = 0
    try:    
        hh_pages_total = int(hh_parsed_html.find_all('a', {'data-qa':'pager-page'})[-1].getText())
    except:
        hh_pages_total = 0
else:
    print('error', response.status_code)

# %%
print(f'на {hh} найдено {hh_vacancies_total}. всего страниц {hh_pages_total}')
input_pages = input('Сколько страниц будем парсить? ')
try:
    hh_pages = int(input_pages)
except:
    hh_pages = 0
if hh_pages > hh_pages_total:
    hh_pages = hh_pages_total
elif hh_pages < 1:
        hh_pages = 0
# Out:
# на https://hh.ru найдено 7 058 вакансий «грузчик». всего страниц 100
# Сколько страниц будем парсить? 4

# %% [markdown]
# #### берем с superjob количество вакансий и страниц по нашему запросу

# %%
response = req.get(sj + f'/vacancy/search/?keywords={search_text}&geo%5Bc%5D%5B0%5D=1', headers=headers)
if response.ok:
    sj_parsed_html = bs(response.text,'lxml')
    try:
        sj_vacancies_total = sj_parsed_html.find('div', {'class':'_1tH7S _1o0Xp GPKTZ _3achh _3ofxL _2_FIo'}).findChild().getText()
    except:
        sj_vacancies_total = 0
    if ('Вакансий не найдено' in sj_vacancies_total) or (sj_vacancies_total == 0):
        sj_pages_total = 0
    else:
        try:
            sj_pages_total = int(sj_parsed_html.find_all('span', {'class':'qTHqo _2h9me DYJ1Y _2FQ5q _2GT-y'})[-2].getText())
        except:
            sj_pages_total = 1
else:
    print('error', response.status_code)

# %%
print(f'на {sj} {sj_vacancies_total} "{search_text}". всего страниц {sj_pages_total}')
input_pages = input('Сколько страниц будем парсить? ')
try:
    sj_pages = int(input_pages)
except:
    sj_pages = 0
if sj_pages > sj_pages_total:
        sj_pages = sj_pages_total
elif sj_pages < 1:
        sj_pages = 0
# Out:
# на https://www.superjob.ru Найдена 32 581 вакансия "грузчик". всего страниц 61
# Сколько страниц будем парсить? 3

# %% [markdown]
# #### ходим по hh и собираем данные

# %%
for page in range(hh_pages):
    response = req.get(hh + f'/search/vacancy?text={search_text}&page={page}', headers=headers)
    if response.ok:
        hh_parsed_html = bs(response.text,'lxml')
        hh_vacancies_block = hh_parsed_html.find('div', {'class':'vacancy-serp'})
        hh_vacancies = hh_vacancies_block.findChildren('div', {'class':'vacancy-serp-item'}, recursive=False)
        get_hh_data(hh_vacancies)
    else:
        continue  
    sleep(rndi(1, 5))

# %% [markdown]
# #### ходим по superjob и собираем данные

# %%
for page in range(sj_pages):
    response = req.get(sj + f'/vacancy/search/?keywords={search_text}&geo%5Bc%5D%5B0%5D=1&page={page + 1}', 
                   headers=headers)
    if response.ok:
        sj_parsed_html = bs(response.text,'lxml')
        sj_vacancies = sj_parsed_html.find_all('div', {'class':'_3zucV _2GPIV f-test-vacancy-item i6-sc _3VcZr'})
        get_sj_data(sj_vacancies)
    else:
        continue
    sleep(rndi(1, 5))

# %% [markdown]
# #### вывод результатов

# %%
df
# Out:
#                                                            vac_name  \
# 1    Грузчик-комплектовщик
# 2    Кладовщик/грузчик-комплектовщик
# 3    Грузчик на склад продуктов питания ( Лобня)
# 4    Грузчик
# 5    Кладовщик-грузчик
# 6    Грузчик-экспедитор (хутор Октябрьский)
# 7    Грузчик
# 8    Заведующий складом
# 9    Грузчик-комплектовщик
# 10   Ночной Грузчик-комплектовщик
# 11   Кладовщик-грузчик
# 12   Грузчик
# 13   Сотрудник склада
# 14   Грузчик-комплектовщик на крупный склад
# 15   Грузчик
# 16   Грузчик
# 17   Грузчик
# 18   Грузчик-комплектовщик
# 19   Комплектовщик-грузчик
# 20   Водитель-экспедитор
# 21   Грузчик-комплектовщик
# 22   Кладовщик (с функциями грузчика)
# 23   Грузчик-комплектовщик
# 24   Грузчик-комплектовщик (м. Варшавская)
# 25   Специалист по персоналу
# 26   Приемосдатчик
# 27   Водитель погрузчика
# 28   Грузчик
# 29   Грузчик
# 30   Грузчик
# ..       ...
# 111  Грузчик на производство
# 112  Грузчик-разнорабочий на производство пластика (вахта с жильём)
# 113  Грузчик (в супермаркет)
# 114  Комплектовщик-грузчик
# 115  Грузчик-комплектовщик на склад
# 116  Грузчик-упаковщик
# 117  Грузчик
# 118  Грузчик (в супермаркет)
# 119  Мерчендайзер-грузчик
# 120  Работник склада / Грузчик (метро Киевская)
# 121  Грузчик (в супермаркет)
# 122  Грузчик (вахта в Москве и МО)
# 123  Грузчик-комплектовщик
# 124  Грузчик кофе
# 125  Грузчик-мерчендайзер (Fix-Price)
# 126  Грузчик на склад
# 127  Грузчик с проживанием
# 128  Грузчик на склад чая (вахта)
# 129  Грузчик на склад
# 130  Грузчик-комплектовщик (вахта от 30 смен с проживанием)
# 131  Грузчик на производство
# 132  Грузчик-разнорабочий на производство пластика (вахта с жильём)
# 133  Грузчик (в супермаркет)
# 134  Комплектовщик-грузчик
# 135  Грузчик-комплектовщик на склад
# 136  Грузчик-упаковщик
# 137  Грузчик
# 138  Грузчик (в супермаркет)
# 139  Мерчендайзер-грузчик
# 140  Работник склада / Грузчик (метро Киевская)
#
#                                                      employer  \
# 1    ООО Транс Альянс Логистик-А
# 2    ООО Стант-Креп
# 3     ВкусВилл
# 4    ТОО Lam.Tech.
# 5     Возим-Бай
# 6     Связной
# 7     Унитарное предприятие «Кока-Кола Бевриджиз Белоруссия».
# 8    ООО ТРЕЙДПАК
# 9    ООО Доминоспицца
# 10    Унитарное предприятие «Кока-Кола Бевриджиз Белоруссия».
# 11    РИВАЛ СВАРКА, ИООО
# 12    1AK-GROUP
# 13    Главсан
# 14   ООО С-Ворк
# 15   ТОО Master Logistic
# 16   УП Моторлэнд
# 17    Оконный континент
# 18    Удачник Сеть магазинов
# 19    Компания КРЕПКО
# 20   ООО Eden Springs
# 21   ООО Сэльвин
# 22   ЗАО МИЛАВИЦА, СП
# 23    СОСЕДИ, Сеть магазинов
# 24    FINN FLARE
# 25    Кадровый советник
# 26    Перекресток
# 27    ИУП БелВиллесден
# 28    Рабочий стандарт (ИП Абылкасанова Ольга Сергеевна)
# 29   ООО АЛС Чита-Лаборатория
# 30   ОАО ЛКХП Кирова
# ..               ...
# 111  Performance Group
# 112  МИКС КЦ
# 113  Лидер Консалт
# 114  JOBTIME
# 115  JOBTIME
# 116  Стафф Маркет
# 117  БИЗНЕС РЕСУРС
# 118  Лидер Консалт
# 119  КС Интернешнл
# 120  Азбука Вкуса
# 121  Лидер Консалт
# 122  Work staff
# 123  Фул Тайм
# 124  СТАФФВОРК
# 125  СТОЛИЦА
# 126  Сеть гипермаркетов "Самбери"
# 127  Ваш Персонал
# 128  МИКС КЦ
# 129  JOBTIME
# 130  МИКС КЦ
# 131  Performance Group
# 132  МИКС КЦ
# 133  Лидер Консалт
# 134  JOBTIME
# 135  JOBTIME
# 136  Стафф Маркет
# 137  БИЗНЕС РЕСУРС
# 138  Лидер Консалт
# 139  КС Интернешнл
# 140  Азбука Вкуса
#
#                                               location min_compensation  \
# 1    Москва, Тверская и еще 2                           60 000
# 2    Гомель                                             900
# 3    Лобня                                              36 000
# 4    Нур-Султан                                         100 000
# 5    Минск, Пролетарская                                700
# 6    Краснодар                                          35 000
# 7    Минск                                              900
# 8    Москва, Озёрная                                    60 000
# 9    Минск                                              600
# 10   Минск                                              800
# 11   Минск                                              800
# 12   Минск                                              650
# 13   Москва, Некрасовка                                 35 000
# 14   Москва                                             None
# 15   Алматы                                             60 000
# 16   Минск                                              1 000
# 17   Москва, Митино                                     45 000
# 18   Минск, Тракторный завод                            700
# 19   Москва, Варшавская                                 35 000
# 20   Москва, Ленинский проспект                         70 000
# 21   Минск                                              700
# 22   Минск                                              660
# 23   Минск                                              900
# 24   Москва, Варшавская и еще 1                         40 200
# 25   Зеленодольск (Республика Татарстан)                20 000
# 26   Воронеж                                            25 000
# 27   Витебск                                            650
# 28   Москва                                             40 000
# 29   Магадан                                            80 000
# 30   Санкт-Петербург, Елизаровская и еще 2              50 000
# ..                                      ...                ...
# 111  Москва,Кантемировская, Варшавская и ещё 2 станции  24 000
# 112  Москва                                             40 000
# 113  Красное Село (Санкт-Петербург)                     25 000
# 114  Калач                                              56 000
# 115  Красноярск                                         56 000
# 116  Клинцы                                             60 000
# 117  Елань                                              35 000
# 118  Красное Село (Санкт-Петербург)                     25 000
# 119  Рязань                                             21 000
# 120  Москва,Киевская                                    33 000
# 121  Всеволожск                                         30 000
# 122  Саратов                                            34 000
# 123  Москва                                             39 000
# 124  Смоленск                                           33 000
# 125  Волгодонск                                         20 055
# 126  Биробиджан                                         25 000
# 127  Волжский                                           49 500
# 128  Москва                                             None
# 129  Жарковский                                         35 000
# 130  Москва                                             45 000
# 131  Москва,Кантемировская, Варшавская и ещё 2 станции  24 000
# 132  Москва                                             40 000
# 133  Красное Село (Санкт-Петербург)                     25 000
# 134  Калач                                              56 000
# 135  Красноярск                                         56 000
# 136  Клинцы                                             60 000
# 137  Елань                                              35 000
# 138  Красное Село (Санкт-Петербург)                     25 000
# 139  Рязань                                             21 000
# 140  Москва,Киевская                                    33 000
#
#     max_compensation   currency  \
# 1    None             руб.
# 2    None             бел. руб.
# 3    None             руб.
# 4    100 000          KZT
# 5    1 000            бел. руб.
# 6    None             руб.
# 7    None             бел. руб.
# 8    70 000           руб.
# 9    700              бел. руб.
# 10   1 800            бел. руб.
# 11   None             бел. руб.
# 12   650              бел. руб.
# 13   None             руб.
# 14   97 000           руб.
# 15   None             KZT
# 16   None             бел. руб.
# 17   None             руб.
# 18   None             бел. руб.
# 19   None             руб.
# 20   None             руб.
# 21   1 100            бел. руб.
# 22   None             бел. руб.
# 23   None             бел. руб.
# 24   57 000           руб.
# 25   40 000           руб.
# 26   45 000           руб.
# 27   None             бел. руб.
# 28   60 000           руб.
# 29   None             руб.
# 30   None             руб.
# ..    ...              ...
# 111  None             ₽
# 112  None             ₽
# 113  None             ₽
# 114  56 000           ₽
# 115  56 000           ₽
# 116  None             ₽
# 117   40 000          ₽
# 118  None             ₽
# 119  None             ₽
# 120  33 000           ₽
# 121  None             ₽
# 122   42 550          ₽
# 123  None             ₽
# 124   72 600          ₽
# 125  None             ₽
# 126   26 000          ₽
# 127   99 000          ₽
# 128  None             None
# 129   45 000          ₽
# 130  None             ₽
# 131  None             ₽
# 132  None             ₽
# 133  None             ₽
# 134  56 000           ₽
# 135  56 000           ₽
# 136  None             ₽
# 137   40 000          ₽
# 138  None             ₽
# 139  None             ₽
# 140  33 000           ₽
#
#                                                                                                link  \
# 1    https://stary-oskol.hh.ru/vacancy/34618992?query=%D0%B3%D1%80%D1%83%D0%B7%D1%87%D0%B8%D0%BA
#