# %% [markdown]
# # Урок 2. Парсинг HTML. BeautifulSoup, MongoDB

# %% [markdown]
# Необходимо собрать информацию о вакансиях на вводимую должность (используем input или через аргументы) с сайта superjob.ru и hh.ru. Приложение должно анализировать несколько страниц сайта(также вводим через input или аргументы). Получившийся список должен содержать в себе минимум:
#
#     *Наименование вакансии
#     *Предлагаемую зарплату (отдельно мин. и отдельно макс.)
#     *Ссылку на саму вакансию
#     *Сайт откуда собрана вакансия
# По своему желанию можно добавить еще работодателя и расположение. Данная структура должна быть одинаковая для вакансий с обоих сайтов. Общий результат можно вывести с помощью dataFrame через pandas.

# %%
from bs4 import BeautifulSoup as bs
import requests as req
import pandas as pd
from random import randint as rndi
from time import sleep

# %%
pd.set_option('display.max_colwidth', -1)

# %% [markdown]
# #### собираем с hh мин, макс зп и валюту зп

# %%
def get_hh_compensations(item):
    try:
        vac_compensation = item.find('div', {'class':'vacancy-serp-item__compensation'}).getText()
    except:
        vac_compensation = None
    if vac_compensation != None:
        vac_compensation = vac_compensation.split(' ')
        comp_curr = vac_compensation[-1]
        if vac_compensation[0] == 'от':
            min_compensation = ''.join(vac_compensation[1:-1])
            max_compensation = None
        elif vac_compensation[0] == 'до':
            max_compensation = ''.join(vac_compensation[1:-1])
            min_compensation = None
        else:
            min_compensation = vac_compensation[0].split('-')[0]
            max_compensation = vac_compensation[0].split('-')[1]   
    else:
        min_compensation, max_compensation, comp_curr = [None] * 3
    return min_compensation, max_compensation, comp_curr

# %% [markdown]
# #### собираем с superjob мин, макс зп и валюту зп

# %%
def get_sj_compensations(item):
    try:
        vac_compensation = item.find('span', {'class':'_3mfro _2Wp8I f-test-text-company-item-salary PlM3e _2JVkc _2VHxz'}).getText()
    except:
        vac_compensation = None
    if vac_compensation != None:
        if vac_compensation == 'По договорённости':
            min_compensation = None
            max_compensation = None
            comp_curr = None
        elif '—' in vac_compensation:
            vac_compensation = vac_compensation.split('—')
            comp_curr = vac_compensation[1][-1]
            max_compensation = vac_compensation[1][:-1]
            min_compensation = vac_compensation[0]
        elif 'от' in vac_compensation:
            vac_compensation = vac_compensation.split()
            comp_curr = vac_compensation[-1]
            max_compensation = None
            min_compensation = ' '.join(vac_compensation[1:-1])
        elif 'до' in vac_compensation:
            vac_compensation = vac_compensation.split()
            comp_curr = vac_compensation[-1]
            max_compensation = ' '.join(vac_compensation[1:-1])
            min_compensation = None
        else:
            vac_compensation = vac_compensation.split()
            comp_curr = vac_compensation[-1]
            max_compensation = ' '.join(vac_compensation[:-1])
            min_compensation = ' '.join(vac_compensation[:-1])
    else:
        min_compensation, max_compensation, comp_curr = [None] * 3
    return min_compensation, max_compensation, comp_curr

# %% [markdown]
# #### собираем с hh остальные данные. vac_name - название вакансии, vac_link - ссылка, employer- работодатель, location - местоположение

# %%
def get_hh_data(vacancies):
    for item in vacancies:
        site_name = hh
        try:
            vac_name = item.find('a').getText()
        except:
            vac_name = None
        try:    
            vac_link = item.find('a')['href']
        except:
            vac_link = None
        try:
            employer = item.find('a', {'data-qa':'vacancy-serp__vacancy-employer'}).getText()
        except:
            employer = None
        try:    
            location = item.find('span', {'data-qa':'vacancy-serp__vacancy-address'}).getText()
        except:
            location = None
        min_compensation, max_compensation, comp_curr = get_hh_compensations(item)
        df.loc[len(df) + 1] = [vac_name, employer, location, min_compensation, max_compensation, 
                                comp_curr, vac_link, site_name]

# %% [markdown]
# #### собираем с superjob остальные данные. vac_name - название вакансии, vac_link - ссылка, employer- работодатель, location - местоположение

# %%
def get_sj_data(vacancies):
    for item in vacancies:
        site_name = sj
        try:
            vacancy = item.find('div', {'class':'_3mfro CuJz5 PlM3e _2JVkc _3LJqf'})
            vac_name = vacancy.getText()
        except:
            vac_name = None
        try:
            vac_link = sj + vacancy.findParent('a')['href']
        except:
            vac_link = None
        try:
            employer = item.find('span', {'class':'_3mfro _3Fsn4 f-test-text-vacancy-item-company-name _9fXTd _2JVkc _3e53o _15msI'}).getText()          
        except:
            employer = None
        try:
            location = item.find('span', {'class':'_3mfro f-test-text-company-item-location _9fXTd _2JVkc _3e53o'}).findChildren(limit=2)[1].getText()
        except:
            location = None
        min_compensation, max_compensation, comp_curr = get_sj_compensations(item)
        df.loc[len(df) + 1] = [vac_name, employer, location, min_compensation, max_compensation, 
                                comp_curr, vac_link, site_name]

# %%
df = pd.DataFrame(columns=['vac_name', 'employer', 'location', 'min_compensation', 'max_compensation',
                          'currency', 'link', 'site_name'])

# %%
user_agent = 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) \
Chrome/78.0.3904.97 Safari/537.36'
headers = {'User-Agent': user_agent}
hh = 'https://hh.ru'
sj = 'https://www.superjob.ru'

# %% [markdown]
# #### фомируем строку для поиска

# %%
search_text = input('Что ищем? ')
if search_text == '':
    search_text = 'Python'
# Out:
# Что ищем?

# %% [markdown]
# #### берем с hh количество вакансий и страниц по нашему запросу

# %%
response = req.get(hh + f'/search/vacancy?text={search_text}', headers=headers)
if response.ok:
    hh_parsed_html = bs(response.text,'lxml')
    try:
        hh_vacancies_total = hh_parsed_html.find('div', {'class':'breadcrumbs'}).next_sibling.getText()
    except:
        hh_vacancies_total = 0
    try:    
        hh_pages_total = int(hh_parsed_html.find_all('a', {'data-qa':'pager-page'})[-1].getText())
    except:
        hh_pages_total = 0
else:
    print('error', response.status_code)

# %%
print(f'на {hh} найдено {hh_vacancies_total}. всего страниц {hh_pages_total}')
input_pages = input('Сколько страниц будем парсить? ')
try:
    hh_pages = int(input_pages)
except:
    hh_pages = 0
if hh_pages > hh_pages_total:
    hh_pages = hh_pages_total
elif hh_pages < 1:
        hh_pages = 0
# Out:
# на https://hh.ru найдено 6 525 вакансий «Python». всего страниц 100
# Сколько страниц будем парсить? 4

# %% [markdown]
# #### берем с superjob количество вакансий и страниц по нашему запросу

# %%
response = req.get(sj + f'/vacancy/search/?keywords={search_text}&geo%5Bc%5D%5B0%5D=1', headers=headers)
if response.ok:
    sj_parsed_html = bs(response.text,'lxml')
    try:
        sj_vacancies_total = sj_parsed_html.find('div', {'class':'_1tH7S _1o0Xp GPKTZ _3achh _3ofxL _2_FIo'}).findChild().getText()
    except:
        sj_vacancies_total = 0
    if ('Вакансий не найдено' in sj_vacancies_total) or (sj_vacancies_total == 0):
        sj_pages_total = 0
    else:
        try:
            sj_pages_total = int(sj_parsed_html.find_all('span', {'class':'qTHqo _2h9me DYJ1Y _2FQ5q _2GT-y'})[-2].getText())
        except:
            sj_pages_total = 1
else:
    print('error', response.status_code)

# %%
print(f'на {sj} {sj_vacancies_total} "{search_text}". всего страниц {sj_pages_total}')
input_pages = input('Сколько страниц будем парсить? ')
try:
    sj_pages = int(input_pages)
except:
    sj_pages = 0
if sj_pages > sj_pages_total:
        sj_pages = sj_pages_total
elif sj_pages < 1:
        sj_pages = 0
# Out:
# на https://www.superjob.ru Найдено 95 вакансий "Python". всего страниц 4
# Сколько страниц будем парсить? 3

# %% [markdown]
# #### ходим по hh и собираем данные

# %%
hh_err_log = {} 
for page in range(hh_pages):
    response = req.get(hh + f'/search/vacancy?text={search_text}&page={page}', headers=headers)
    if response.status_code == 200:
        hh_parsed_html = bs(response.text,'lxml')
        hh_vacancies_block = hh_parsed_html.find('div', {'class':'vacancy-serp'})
        hh_vacancies = hh_vacancies_block.findChildren('div', {'class':'vacancy-serp-item'}, recursive=False)
        get_hh_data(hh_vacancies)
    else:
        hh_err_log[page + 1] = response.status_code
        continue  
    sleep(rndi(1, 5))  
if hh_err_log != {}:
    print('не все прошло гладко - "номер страницы":"статус запроса"', hh_err_log)

# %% [markdown]
# #### ходим по superjob и собираем данные

# %%
sj_err_log = {}
for page in range(sj_pages):
    response = req.get(sj + f'/vacancy/search/?keywords={search_text}&geo%5Bc%5D%5B0%5D=1&page={page + 1}', 
                   headers=headers)
    if response.status_code == 200:
        sj_parsed_html = bs(response.text,'lxml')
        sj_vacancies = sj_parsed_html.find_all('div', {'class':'_3zucV _2GPIV f-test-vacancy-item i6-sc _3VcZr'})
        get_sj_data(sj_vacancies)
    else:
        sj_err_log[page + 1] = response.status_code
        continue
    sleep(rndi(1, 5))
if sj_err_log != {}:
    print('не все прошло гладко - "номер страницы":"статус запроса"', sj_err_log)

# %% [markdown]
# #### вывод результатов

# %%
df
# Out:
#                                                                   vac_name  \
# 1    Python Developer
# 2    Data Analyst
# 3    Junior QA Automation Engineer
# 4    Старший тестировщик ПО
# 5    Middle Python Developer
# 6    Kubernetes Engineer
# 7    Senior Python Developer
# 8    Data Engineer
# 9    QA Automation Engineer
# 10   Junior data engineer (внедрение моделей)
# 11   Инженер по тестированию / QA Engineer
# 12   Старший специалист по тестированию ПО
# 13   Python Back-end Developer
# 14   QA Automation Engineer
# 15   QA Automation Engineer
# 16   Data Analyst (Senior)
# 17   Senior C++ Developer (Videostreaming)
# 18   Ведущий разработчик Python / Software development / Team lead
# 19   Team Lead Data Science (предиктивная аналитика)
# 20   QA Automation Engineer
# 21   Веб-аналитик
# 22   DevOps engineer
# 23   Scala Developer (Java / C++ / С# / Python)
# 24   Разработчик Scala / Middle Scala Developer (Java / C++ / С# / Python)
# 25   Senior data engineer
# 26   Аналитик – urban data scientist
# 27   Scala Developer (Java / C++ / С# / Python)
# 28   Математик
# 29   Middle/ Senior Data Scientist (NLP)
# 30   Middle/ Senior Data scientist (speech recognition)
# ..                                                  ...
# 111  Системный администратор
# 112  Главный аналитик (SQL, OLAP)
# 113  Системный администратор Linux
# 114  Младший системный администратор Linux
# 115  Системный администратор Linux
# 116  Разработчик
# 117  Педагог дополнительного образования (программирование)
# 118  Аналитик
# 119  Специалист по автоматизированному тестированию
# 120  Веб-программист
# 121  Главный инженер в отдел баз данных Hadoop и NoSQL
# 122  Разработчик в отдел технических средств обучения (C++ / Qt)
# 123  Инженер-программист
# 124  Ведущий data scientist
# 125  Системный администратор
# 126  Web-программист
# 127  Системный администратор Linux
# 128  Инженер-программист Delphi
# 129  Аналитик по прогнозированию
# 130  Инженер (программирование)
# 131  Ведущий эксперт по СУПП
# 132  Релиз-инженер
# 133  Инженер, техник
# 134  Системный администратор
# 135  IT-специалист
# 136  Программист-разработчик
# 137  Преподаватель по робототехнике (Новобайдаевский р-н)
# 138  Системный администратор
# 139  Программист-тестировщик
# 140  JavaScript developer (gamedev)
#
#                                                     employer  \
# 1     Emerline
# 2     Ренессанс cтрахование, Группа
# 3     Searchinform
# 4     SOVA CAPITAL LIMITED
# 5    ООО Кайриба Инжиниринг
# 6    ООО Рекон Групп
# 7     ДомКлик
# 8    ООО Плейджендари Девелопмент
# 9     Searchinform
# 10    Сбербанк для экспертов
# 11   ООО Смарт Дельта Системс
# 12    CBS Interactive
# 13   ООО Эпика Девелопмент
# 14    Searchinform
# 15    Searchinform
# 16    Сбербанк для экспертов
# 17   ООО Риал Тайм Технологии
# 18    CATAPULTO.RU
# 19    Сбербанк для экспертов
# 20    Searchinform
# 21   ООО ЮрСпектр
# 22    Мобильные ТелеСистемы (МТС), Беларусь
# 23    NAUMEN
# 24    NAUMEN
# 25    Сбербанк для экспертов
# 26   ООО Ситимейкерс
# 27    NAUMEN
# 28    Частное предприятие AйФьючер / iFuture
# 29    ЦРТ | Группа компаний
# 30    ЦРТ | Группа компаний
# ..                      ...
# 111  Агентство недвижимости "Экотон"
# 112  Росгосстрах
# 113  Самсон-опт
# 114  Самсон-опт
# 115  Интернет-Космос
# 116  МегаФон
# 117  ГБОУ СОШ №619 Калининского района Санкт-Петербурга
# 118  ИК СИБИНТЕК
# 119  Опти-Софт
# 120  None
# 121  Сбербанк России
# 122  ПАО "Компания "Сухой"
# 123  ВНИИФТРИ
# 124  «Деловые Линии»
# 125  ЭКО центр АльтраВита
# 126  Фирма ВОДОКОМФОРТ
# 127  НПФ "ХЕЛИКС"
# 128  БСКБ "Нефтехимавтоматика"
# 129  Hoff
# 130  ВНИИФТРИ
# 131  «Т Плюс»
# 132  Э-Студио
# 133  ВНИИФТРИ
# 134  ПРИМА
# 135  Анкор
# 136  Промотрейд (Кадровая Служба 24)
# 137  Академия 42
# 138  Филиал ФКУ «Налог-Сервис» ФНС России по ЦОД в г. Москве
# 139  "Концерн "Автоматика", АО "БПО "Прогресс"
# 140  None
#
#                               location min_compensation max_compensation  \
# 1    Минск, Уручье                      None             None
# 2    Москва, Павелецкая и еще 3         None             None
# 3    Ростов-на-Дону                     60 000           80 000
# 4    Москва, Добрынинская               None             None
# 5    Минск                              None             None
# 6    Санкт-Петербург, Адмиралтейская    200 000          None
# 7    Москва, Кутузовская                None             None
# 8    Минск                              None             None
# 9    Астрахань                          120 000          150 000
# 10   Москва                             None             None
# 11   Москва, Бауманская                 80 000           110 000
# 12   Москва, Павелецкая                 None             150 000
# 13   Минск, Автозаводская               None             None
# 14   Ростов-на-Дону                     120 000          150 000
# 15   Санкт-Петербург                    120 000          150 000
# 16   Москва                             None             None
# 17   Санкт-Петербург                    180 000          None
# 18   Москва                             200 000          None
# 19   Санкт-Петербург                    None             None
# 20   Минск                              2 000            None
# 21   Минск                              2 100            2 200
# 22   Минск, Парк Челюскинцев            1 500            None
# 23   Москва                             None             None
# 24   Тверь                              None             None
# 25   Москва                             None             None
# 26   Москва                             None             None
# 27   Екатеринбург                       None             None
# 28   Минск, Институт Культуры и еще 1   None             None
# 29   Санкт-Петербург, Выборгская        None             None
# 30   Санкт-Петербург                    None             None
# ..               ...                     ...              ...
# 111  Санкт-Петербург                    55 000           None
# 112  Москва,Калужская, Чертановская     None             None
# 113  Воронеж                            70 000           None
# 114  Воронеж                            54 000           None
# 115  Москва                             None             None
# 116  Новосибирск                        None             None
# 117  Санкт-Петербург                    None             None
# 118  Рязань                             33 000           None
# 119  Петрозаводск                       45 000           None
# 120  Комсомольск-на-Амуре               64 000            80 000
# 121  Хабаровск                          None             None
# 122  Москва                             60 000            100 000
# 123  Зеленоград                         40 000           None
# 124  Санкт-Петербург                    None             None
# 125  Москва                             64 000           None
# 126  Москва,Павелецкая                  None             None
# 127  Санкт-Петербург,Петроградская      None             None
# 128  Уфа                                None             None
# 129  Москва,Улица 1905 года             None             None
# 130  Зеленоград                         40 000           None
# 131  Екатеринбург                       None             None
# 132  Йошкар-Ола                         30 000           None
# 133  Зеленоград                         35 000           None
# 134  Москва,Ховрино                     50 000           None
# 135  Калуга                             None             None
# 136  Самара                             80 000           None
# 137  Новокузнецк                        None             None
# 138  Волгоград                          30 000           None
# 139  Уфа                                20 000           None
# 140  Санкт-Петербург                    120 000          120 000
#
#       currency  \
# 1    None
# 2    None
# 3    руб.
# 4    None
# 5    None
# 6    руб.
# 7    None
# 8    None
# 9    руб.
# 10   None
# 11   руб.
# 12   руб.
# 13   None
# 14   руб.
# 15   руб.
# 16   None
# 17   руб.
# 18   руб.
# 19   None
# 20   USD
# 21   бел. руб.
# 22   бел. руб.
# 23   None
# 24   None
# 25   None
# 26   None
# 27   None
# 28   None
# 29   None
# 30   None
# ..    ...
# 111  ₽
# 112  None
# 113  ₽
# 114  ₽
# 115  None
# 116  None
# 117  None
# 118  ₽
# 119  ₽
# 120  ₽
# 121  None
# 122  ₽
# 123  ₽
# 124  None
# 125  ₽
# 126  None
# 127  None
# 128  None
# 129  None
# 130  ₽
# 131  None
# 132  ₽
# 133  ₽
# 134  ₽
# 135  None
# 136  ₽
# 137  None
# 138  ₽
# 139  ₽
# 140  ₽
